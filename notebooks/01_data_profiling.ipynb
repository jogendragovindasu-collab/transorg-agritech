# %% [markdown]
# # 🌾 Data Profiling Notebook
# ### Step 1: Inspect and understand raw datasets before writing cleaning logic.
#
# This notebook will be used to:
# - Load raw files from `data/raw/`
# - Check missing values, data types, and column names
# - Identify inconsistent entries (crop names, mandi locations, price anomalies)
# - Document findings in `data_dictionary.md`

# %%
# Imports
import pandas as pd
import numpy as np
from pathlib import Path

# Set paths
RAW_DIR = Path("../data/raw")
list(RAW_DIR.glob("*"))  # List all raw files
